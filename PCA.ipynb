# %%
# === C. Performance Comparison ===

xgb_acc = 0.978
xgb_time = 30.0
acc4=0.9763
time4=64.25
cnn_acc=0.9896
cnn_time=247.55
lenet_acc=0.9824
lenet_time=71.18
# Print comparison table
print("=== Performance Comparison ===")
print(f"XGBoost (Assignment 1)   → Accuracy: {xgb_acc:.4f}, Time: {xgb_time:.2f}s")
print(f"MLP (5-layer, ReLU+Adam) → Accuracy: {acc4:.4f}, Time: {time4:.2f}s")
print(f"CNN (4-layer)            → Accuracy: {cnn_acc:.4f}, Time: {cnn_time:.2f}s")
print(f"leNet-18                → Accuracy: {lenet_acc:.4f}, Time: {lenet_time:.2f}s")

best_model = max([
    ("XGBoost", xgb_acc),
    ("MLP", acc4),
    ("CNN", cnn_acc),
    ("leNet-18", lenet_acc)
], key=lambda x: x[1])

print(f"\n Best Performing Model: {best_model[0]} with Accuracy: {best_model[1]:.4f}")
# Out:
# === Performance Comparison ===
# XGBoost (Assignment 1)   → Accuracy: 0.9780, Time: 30.00s
# MLP (5-layer, ReLU+Adam) → Accuracy: 0.9763, Time: 64.25s
# CNN (4-layer)            → Accuracy: 0.9896, Time: 247.55s
# leNet-18                → Accuracy: 0.9824, Time: 71.18s
#
#  Best Performing Model: CNN with Accuracy: 0.9896
